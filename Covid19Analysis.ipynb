# %% [markdown]
# <a href="https://colab.research.google.com/github/wavemx/covid19/blob/master/Covid19Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import Covid19Analysis
# %matplotlib inline

# %%
data = Covid19Analysis.get_data()
Covid19Analysis.plot_case_by_country(data, 'US', None)
#Covid19Analysis.plot_active_cases(data, 'US', None)
Covid19Analysis.plot_new_cases(data, 'confirmed', 'US', None)
Covid19Analysis.plot_new_cases(data, 'death', 'US', None)
Covid19Analysis.plot_compare_first(data, 100, 'confirmed', ['US', 'China', 'Italy', 'Spain', 'United Kingdom', 'Germany', 'Poland', 'Bulgaria', 'Mexico', 'Russia'])
Covid19Analysis.plot_compare_first(data, 100, 'death', ['US', 'China', 'Italy', 'Spain', 'United Kingdom', 'Germany', 'Poland', 'Bulgaria', 'Mexico', 'Russia'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
